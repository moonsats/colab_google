# %%
# -*- coding=utf-8 -*-
"""
주요 기능: GoogleAuth  Google 인증 토큰 획득
    - GCP(Google Cloud Platform)에서 생성한 id/account/key 사용
        - user_nick(OAuth 2.0 Client ID)
        - bot_nick(Service Account)
        - api_key(API Key)  ## 구현되어 있지 않음
    - 현재 계정의 auth 사용
        - colab_auth: from colab import auth  auth.authenticate_user()

사용 방법: 
    - user_nick: gauth = GoogleAuth(user_nick="satsbymoon")  gd = GoogleDrive(gauth)
    - bot_nick: gauth = GoogleAuth(bot_nick="mats")  gd = GoogleDrive(gauth)

참조 자료:
    - 

필요 환경:
    - json 파일 생성 및 저장
        - user_nick
        - bot_nick
        - api_key
        - colab_auth
    - pip requirements:

"""

##@@@ Package/Module
##============================================================

##@@ Built-In Package/Module
##------------------------------------------------------------
import os, sys
import json
from pprint import pprint

## cURL 용
import subprocess
import io
from urllib.parse import urlparse, urlencode

##@@ External Package/Module
##------------------------------------------------------------

from googleapiclient.discovery import build
from google_auth_oauthlib.flow import Flow, InstalledAppFlow
# from googleapiclient.http import MediaFileUpload, MediaIoBaseDownload
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

from oauth2client.service_account import ServiceAccountCredentials  ## bot_nick



##@@ User Package/Module
##------------------------------------------------------------

##@@@ Constant/Varible
##============================================================

## Local(PC Drive) 환경인지 Cloud(Google Drive) 환경인지 확인
ENV = "_LOCAL_"
if "content" in os.getcwd():
    ENV = "_GDRIVE_"

##@@ Constant
##------------------------------------------------------------

PATH_CONFIGS = "./configs"  if ENV == "_LOCAL_" else "/content/drive/MyDrive/__COLAB/CONFIGS/GOOGLE/"

##@@ Variable(Golobal)
##------------------------------------------------------------


##@@@ Private Function
##============================================================

##@@ path, credentials
##------------------------------------------------------------
def _get_path(path_type, nick="", settings_folder=PATH_CONFIGS):
    """

    """
    path = settings_folder[:-1] if settings_folder[-1] == "/" else settings_folder
    if path_type == 'token': # access token
        path += f"/{nick}_cred_token.json"
    elif path_type == 'user':  # client credentials
        path += f"/{nick}_cred_user.json"
    elif path_type == 'bot':  # client credentials
        path += f"/{nick}_cred_bot.json"
    elif path_type == 'spec':  # api spec(version, scope)
        path += f"/{nick}_api_spec.json"

    return path


def _set_credentials_by_user_from_sheets(user_nick):
    # TODO: 
    pass


def _set_credentials_by_user(nick):
    path_token = _get_path("token", nick=nick)
    path_user = _get_path("user", nick=nick)
    # api_spec = _get_path("spec", nick=nick)
    api_spec = json.load(open(_get_path("spec", nick=nick), "r", encoding="utf-8"))
    scopes = api_spec['scopes']
    creds = Credentials.from_authorized_user_file(path_token, scopes) if os.path.exists(path_token) else None

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            # flow = InstalledAppFlow.from_client_secrets_file(PATH_CLIENT_SECRET.format(nick=nick), scopes)
            # https://google-auth-oauthlib.readthedocs.io/en/latest/reference/google_auth_oauthlib.flow.html
            # from_client_config(client_config, scopes, **kwargs)
            # from_client_secrets_file(client_secrets_file, scopes, **kwargs)
            flow = InstalledAppFlow.from_client_secrets_file(path_user, scopes)
            creds = flow.run_local_server(port=0)
        with open(path_token, 'w') as token:
            json.dump(json.loads(creds.to_json()), token, ensure_ascii=False, indent=4)
    
    # creds_info = {'creds': creds, 'version': api_spec['version']}
    # # creds_info = json.loads(creds.to_json())
    # creds_info['version'] = api_spec['version']
    return {'credentials': creds, 'version': api_spec['version']}


def _set_credentials_by_bot(nick):
    path_bot = _get_path("bot", nick=nick)
    api_spec = _get_path("spec", nick=nick)
    api_spec = json.load(open(_get_path("spec", nick=nick), "r", encoding="utf-8"))
    scopes = api_spec['scopes']

    credentials = ServiceAccountCredentials.from_json_keyfile_dict(
        json.load(open(path_bot, "r", encoding="utf-8")), 
        api_spec['scopes']
    )

    return {'credentials': credentials, 'version': api_spec['version']}


def _create_credentials(user_nick=None, bot_nick=None):
    if user_nick:
        return _set_credentials_by_user(nick=user_nick)
    elif bot_nick:
        return _set_credentials_by_bot(nick=bot_nick)
    else:
        return None


# ##@@ service
# ##------------------------------------------------------------
def _create_service_by_user_nick(api_name="sheets", nick=None, creds=None):
    try:
        service = build(api_name, creds['version'][api_name], credentials=creds['credentials'])
        print(f'{api_name} service(user_nick: {nick}) created successfully')
        return service
    except Exception as e:
        print(f'Unable to connect\n{e}')
        return None


def _create_service_by_bot_nick(api_name="sheets", nick=None, creds=None):
    try:
        service = build(api_name, creds['version'][api_name], credentials=creds['credentials'])
        print(f'{api_name} service(bot_nick: {nick}) created successfully')
        return service
    except Exception as e:
        print(f'Unable to connect\n{e}')
        return None


def _create_service(api_name, user_nick=None, bot_nick=None, creds=None):

    if user_nick:
        return _create_service_by_user_nick(api_name, nick=user_nick, creds=creds)
    elif bot_nick:
        return _create_service_by_bot_nick(api_name, nick=bot_nick, creds=creds)
    else:  ## colab auth
        pass


##@@@ Main Class
##============================================================
class GoogleAuth():
    def __init__(self, user_nick=None, bot_nick=None):
        creds_info = _create_credentials(user_nick=user_nick, bot_nick=bot_nick)
        self.credentials = creds_info['credentials']  # credentials
        self.version = creds_info['version']
        creds = json.loads(self.credentials.to_json())
        self.token = creds.get('token', None)
        
        # self.scopes = json.loads(self.credentials['credentials'].to_json())['scopes']
        # self.service = _create_service(api_name, user_nick=user_nick, bot_nick=bot_nick, creds=self.creds)
        # self.mime_type = _set_map_mime_type()


##@@@ Main Function
##============================================================
if __name__ == "__main__":
    pass
    ## path, credentials
    # user_nick = "moonitdev"
    user_nick = "satsbymoon"
    # # user_nick = "master"
    # bot_nick = "moonsats"

    ## NOTE: GoogleAuth
    gauth = GoogleAuth(user_nick=user_nick)
    # gauth = GoogleAuth(bot_nick=bot_nick)
    gds = build("drive", gauth.version["drive"], credentials = gauth.credentials)
    r = gds.files().list().execute()

    ## meta_data
    # r = gds.files().get(fileId="11XdqELYDyDea_4YLmJHSjSrimazLdtr-").execute()
    # 1ywx8F3Ujx0wH093wznXf0qgYo1mhKDRs
    # r = gds.files().get(fileId="1lJM_TdveFaVpieRBxvbDhYp6dQoKhFhc").execute()
    # r = gds.files().list(q="parents = '1ywx8F3Ujx0wH093wznXf0qgYo1mhKDRs' and trashed=false").execute()
    # file_id = "1m1iHuKPn_rQji2ByDyOHQZTAS6KQUTSW"
    # r = gds.files().copy(fileId="1m1iHuKPn_rQji2ByDyOHQZTAS6KQUTSW", body=dict(name="__GoogleREST.ipnb", mimeType="application/vnd.google.colaboratory")).execute()
    pprint(r)


    # # ##@@ NOTE: drive
    # gds = GoogleAPI("drive", user_nick=user_nick, bot_nick=None)
    # l = gds.token
    # # l = gds.list(queries=["parents = '1cXwU3nf9_CldBFWzb8DzJqlgs3sDyc7P'"], out_type="list")
    # # l = gss.id_by_name(name="Master_Configs_Google", app="sheets")
    # print(l)
    
    # gss = Google("sheets", user_nick=None, bot_nick=bot_nick)
# Out:
# {'files': [{'id': '1Nd5QRWfXCdS8UrATBb-WnSjTLH-Uj2P0',
#             'kind': 'drive#file',
#             'mimeType': 'text/plain',
#             'name': 'test.txt'},
#            {'id': '1cQc9Q9YITps15x5c0kbZlPpsadY7T-U1',
#             'kind': 'drive#file',
#             'mimeType': 'text/plain',
#             'name': 'test.txt'},
#            {'id': '1tMLK_aYO5f2SIYgBYE7pDD64nfDJWfzGcsOtEVOiCwQ',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.spreadsheet',
#             'name': 'colab 사용 유의사항'},
#            {'id': '1mAIJ_tu4CN81oLXmqHMlOumfR-ezjQqz',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleDrive.ipynb'},
#            {'id': '1jVOmj_-RTjv1Pec28WCxpn9c3oJm_cjn',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleAPI.ipynb'},
#            {'id': '1lJM_TdveFaVpieRBxvbDhYp6dQoKhFhc',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleAuth.ipynb'},
#            {'id': '1RUWggODy2BGdQG1FQlZd2hbQwhFfyL_W',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'satsbymoon_cred_token.json'},
#            {'id': '1sbIbVODJniXPfI4-i7eoMKavWoFcobBZ',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'satsbymoon_cred_user.json'},
#            {'id': '1XH99sIm-zUvmi7k_sxDvpCbC4hVebXOg',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': '__satsbymoon_cred_token.json'},
#            {'id': '1mRYL_Z6G2rhZg0qE6nUnZ689b3jo5NZt',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': '__satsbymoon_cred_auth.json'},
#            {'id': '164XWhfP1MEDgy6w4kOpfVNPPOKT9aL9x',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'moonsats_api_spec.json'},
#            {'id': '15weqXaAo6Oz8OH7lMmMAJlE1oCwBtQ5C',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleAccount.ipynb'},
#            {'id': '1QWfCC2gb2KeG4CCPZFbkLA82A35Cq7NM',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'moonsats_cred_bot.json'},
#            {'id': '11XdqELYDyDea_4YLmJHSjSrimazLdtr-',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleColab.ipynb'},
#            {'id': '1B5PeKCZNe3Wt0U6nnkB8iccqrok6L8TV',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': '__mime_type.json'},
#            {'id': '1xfuM0ZdwP2NVDGnGdBIn-fVpLtNHgrLK',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': '__Template.ipynb'},
#            {'id': '1f9mEn-l3jJGVmNcvKY4MDtHypW1cG-Wr',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleREST.ipynb'},
#            {'id': '1AfvK99S5IASHwdAQ9t0THhe0Oti1gn5d',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': '[매일 10분 데이터 분석] 날짜데이터를 처리 하자! 1편 (python / date time / '
#                     'pandas).ipynb'},
#            {'id': '11LTtRYU-qXXcDzqmeYk-JZjZoL1dGJgv',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'Untitled'},
#            {'id': '17xfub0RDtsTE4Deb--E4aB4kwWLKiQhl',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': '[매일10분데이터분석]08_SQL연동해서_사용하기.ipynb'},
#            {'id': '1zu1TyWMw5WxkTB9t7pxHSVeJjBwxbf8V',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleShell.ipynb'},
#            {'id': '19omJNUXYUuOp2gEgY1p-nWGIOGX29zpG',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'GoogleRestAPI.ipynb'},
#            {'id': '1aaE551eLJjotRJ3taZnJXk7fYB709B8Y',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': '__default_api_spec.json'},
#            {'id': '1EJ9X6YVYd_hsMkz1zE0cLbrZ1-n1NlfX',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': '_mats_cred_bot.json'},
#            {'id': '1pwiyygpiK8RIAqjUhFdza-HVJp7sTNa8',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'satsbymoon_api_spec.json'},
#            {'id': '1Xhq5MXIkbWu59LzoFQcG0TM82vtZXAoQ',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'moonitdev_cred_token.json'},
#            {'id': '1AxXgPIrhStnSE8bDeDkUQZO6EHcu0zUc',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'master_cred_user.json'},
#            {'id': '1V2Cq2GxdunZvIPYHTeC5jT82zINWeILD',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'moonitdev_cred_user.json'},
#            {'id': '1lX6Dn_ec-AE4vQW2WSwctU79tHv6ACZW',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'satsbymoon_cred_user.json'},
#            {'id': '1cnXdjd_Ai48A51591RHgbDukcFPsnN3i',
#             'kind': 'drive#file',
#             'mimeType': 'application/json',
#             'name': 'master_cred_token.json'},
#            {'id': '1H4A_4hyRHJUvyDkuCcWhXvWUYe_4PMQz',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.folder',
#             'name': 'TEST2'},
#            {'id': '1IBfGzsJMaFn0gYes6iJGmgka36v1aeHu',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.folder',
#             'name': 'TEST1'},
#            {'id': '1d2HmMAYmgtsv6e5ugxW696JExBmvAYAp_-jxioY2qLw',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.spreadsheet',
#             'name': 'test_'},
#            {'id': '1iNI6BdJ4f8SztCFRtvEEEoIXmzIqnyQhqrar1btoJ1k',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.spreadsheet',
#             'name': 'Master_Configs_Google'},
#            {'id': '1PPqURA897rVYMyHAfZlOqm1nrGrRgA44',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'github.ipynb'},
#            {'id': '1cTR2bPfDw3blVwslccGeWhsJEZyMiqVX',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'googleManager.ipynb'},
#            {'id': '19LTNbSnALoGN0z_1LJi0-r1MdNBNcoJO',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogeSheets.ipynb'},
#            {'id': '1vBYkAFW5H2oFJW1eCtfIAjy5cugUHD3O',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'GoogleAPI.ipynb'},
#            {'id': '1PU34J8XNo-XOx6CQDCRxi4zG8QCiaL-N',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.folder',
#             'name': 'GOOGLE'},
#            {'id': '1CL_aLirY-RDUI1Uwp0WrgOa-gPyqpTJ0foWQ_-hQw_A',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.spreadsheet',
#             'name': 'public_access'},
#            {'id': '19-vS4UX8Jvi-3P_oAU8DYFWlkcrsRtX-',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.folder',
#             'name': 'SPECS'},
#            {'id': '1roP71P1BIJzB9NoCLeHvyBHAUGDN77Mz',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'localRuntime.ipynb'},
#            {'id': '1Og7AD2onhq87Mbx19B8zGEqtf1I4Teh7',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': '로컬 런타임.ipynb'},
#            {'id': '1JTVIsWQlIyUhhpFrGQz1ULM9wQmB8p7Z',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google.colaboratory',
#             'name': 'loadExcel.ipynb'},
#            {'id': '1YhUYIxH1aqQixES8D9CGh9oCTrrUHfGr',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#             'name': '__api_requests_ebest.xlsx'},
#            {'id': '1qi-6MA5QjgQqFEv0hpo0Jog7lAT0Ka0vUu_XSj26Mqs',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.spreadsheet',
#             'name': '_api_requests_ebest'},
#            {'id': '1Ed9dmHik9DuxfJDBGzejN0WY828MU6pWD2emepPQNmY',
#             'kind': 'drive#file',
#             'mimeType': 'application/vnd.google-apps.spreadsheet',
#             'name': 'codes'},
#            {'id': '12KYj_UAns-R_IaZmKSnTQYI4dNphupQZ',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'main'},
#            {'id': '12481BjHUjbcflbTh5xKOVV3QQ4ujKbQl',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'main'},
#            {'id': '1-tgBVo_lQtk-BGxGPG7W8LgGT4RC3cCl',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'HEAD'},
#            {'id': '1UyPG-LgVZIeya8DkpIiRTZUGM2Urm1Kp',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'd49a16f53bb85c556c6601983bd40321b18043'},
#            {'id': '1V5Sohp104MiXjqa1lM-AJIy2vURE28qf',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'COMMIT_EDITMSG'},
#            {'id': '1-AVjlg1X8Rg5PMO-8Ly-f8DCvCKcn2qE',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'index'},
#            {'id': '1UbRwrpu-xeaDokaZaw9baIWJwbP0prEI',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '9f36444f454ed99804b426371b2f73f32c45fb'},
#            {'id': '1UeepKglvARawXML2WtZJd6wA9OM0h8n0',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'a68faad29a0980663312a15556a05ce90bb3ab'},
#            {'id': '1UhVW67sdNxdwpPz6cYom-eOOJs6FYoyf',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '042808984200755d6a4e4b19d385dcd2438eab'},
#            {'id': '1UnQcJ_WsIrol2uf0WfbtCuT56i11XrG9',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'cdb7cb4c6e7cbe2522ea2634147194d2eebcdf'},
#            {'id': '1UsgYy4aI8WQhOXUKcAS82W-XOJxJr-Kf',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'db4681eecb1b0b70a56e65644f31e25b31c28a'},
#            {'id': '1UHmlD_2m7P8x6R7POmdyujMFjK663CuT',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'db3ed25ba9e47a78f86be368ed00e74800df92'},
#            {'id': '1UJCL7iTX6NlbmYYpEFzfDdVOsNKHRU-G',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'c6b48e7e745b78668d73d01ecb7d1fa5f4382b'},
#            {'id': '1UMTn8DGhgsghJSstipNuh28DEfNeu9Og',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'f0810ec1a0239b5733f42e2b177855f62da731'},
#            {'id': '1UOFFZJdWXpbqyhVJmlnFuZMdIkB5zFNa',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '33e9be1954de59474e9f3cf2ce91ff2a22b208'},
#            {'id': '1UUK-t4Pt-f2BEvF4m8DN8ii7tysq3jaW',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '6c4bdf077bc0d691ae7359c00df55cd00b34ed'},
#            {'id': '1UUVAMwLOkLviiRJ1KphruAUqkhatPktz',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'a91c710c6e057763a3d1725aa1526e07bd3a2e'},
#            {'id': '1UYA_jhStp4RoHx_MehYXcWuqlQc_ndCk',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '22ffaf549ed7daf305ff34eaa8a93db5b8f7e1'},
#            {'id': '1UZ3U5FIZhUr7XQsye6qu0bDmPnmHSTll',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '78dd6a5f096214008861553475ddd030399b56'},
#            {'id': '1U_LL8OivPZGOc0YbW_eyuR5pbdhl9rWx',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '3d7183eda896dcc272a58230edf642f429304e'},
#            {'id': '1U_qbAu59GXmnnr8jniZNF1NhEvq08BDa',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '8600c4a594a1a2050ca600ca6b2e7ed0f08906'},
#            {'id': '1UafeVrkpSLD-M7sbERsamu5-6kb2zt-O',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '65c77a127e3dd5bfc48c3ca581e1c896ab58b9'},
#            {'id': '1Tonv9MmL3LiIZjh0yFCNK2lz8Sj7jveO',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'e2c35a32a9ee1cbeaac8b3f6dec1623821d6ce'},
#            {'id': '1TsOdS0ylYwA6Ne07B1Kj9dEU0geQL8NL',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '83dcd2910b6a1e64097e3a5f0f95da01024779'},
#            {'id': '1TvxfEfPF4jLtMvdgkkYDtikUJ4x0mVcN',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '75544ff616ba2fcd01ed4dde50d2e7833c4b29'},
#            {'id': '1TzgG0ouq5p9m0EfC-7zLw2iiOmCtRniV',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '85ac6314a828c4afcafba43c2de00a1860e476'},
#            {'id': '1U3OcNcLTUS-xo77H2QH7B5oIU9FS9DOG',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'c41cbb4192e6d8f14244e4f70c80ba48368264'},
#            {'id': '1U5zd5Qr3qLccinGAMa8Nz0_PEd70PS5d',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'd026ca450716e3e82826222a6223c07e336e82'},
#            {'id': '1U8AJtof52k9toPlufPJGKKzhenJdj88G',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '8bb73ae7111d72f394ceb3ccbff997064671f0'},
#            {'id': '1U8jTge4vNp2UaA2kTaw1aZpsEnuDzRxq',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '1021d00ee65d7187fe21fa2dac3d97765fa6ee'},
#            {'id': '1UAJVG_uMPUqKuepuARQiyjwBBxJ4_tJQ',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '1a798ad6bd7237ed3263f13e6af3127f53882f'},
#            {'id': '1UEiX-hzHltxx11CCGxhaZD1e96AKvnlq',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '5ee8e32879c059d806db361aa42188fb586a47'},
#            {'id': '1UHk58oClHnpFpSeRB52gzHzhAMQTLytg',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'd59b87a7e300aee4b77ff808a5199617499b9b'},
#            {'id': '1TBlxrfy4w0PyvsDPOm6sLBP8T62DGO7D',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'a43bb33c190a4e6a1bf2da80d348e18f3acbb7'},
#            {'id': '1TCBzn3GqBTzUTV09_pm6XwdT-FljJlN9',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '726068c342f6b24e4bccc8684ce08cf22ec13d'},
#            {'id': '1TDmacbz9vxylPG3jCqfKzWZQuXd-GpcY',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'acc30710f4d4a5d6ee0d8aa834f1adee9d0349'},
#            {'id': '1TE04hiPuQmcbX9diMzSBzJ3kEDDFgmPs',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '9ef3e7933b194d422937f4732af10dcc5cb21d'},
#            {'id': '1TKSOVKJ1tbOLxsdFal_fqCE7_ZrFvTXs',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'e4eb302451bb95f5c7f35de0554c0d855aab01'},
#            {'id': '1TNZeMZn2GLEyXjT07skusiJIz6xPKoQQ',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '0464b57f1b94d25b7b07b30d925e7105426ffe'},
#            {'id': '1TR3m7-BbhMbV645fzeGZkxTzkb6jtoB5',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '996620dbef2fd8c4b6f0dbca95c24582634ba8'},
#            {'id': '1TRFhINi-oWomaJrwuVUjCDQvrmwVZ1Ga',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '507b2257f4faad4d3fc3147aa54e2fe9da848b'},
#            {'id': '1TV5lj0MZpmWL5jyXrazg6bMfu-EKQMyW',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '3ada7c67a56ceb1f50d458570dee59816b6899'},
#            {'id': '1ThHqH_1qAmpOaAsbo2GcvR1u-hTh7LF_',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'acccc5a0d6f3116d6f0e8715642ab8acd0afd2'},
#            {'id': '1Tm-mcgb6wX_5rPwvbONgJBdXwf2tcnL7',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '333a5c5756a238f794935ba958733b28e5cc9a'},
#            {'id': '1SWaDa922So9DiJPOAEKE1XxJgw20LJXd',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '24f44719f73c7dea7a2b236ad17f08f904d2e9'},
#            {'id': '1SZMB5PCGyz_3M8VLugyLn3GYYFdMMsUu',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '55099db16c6b03a70ae5a90b24339b0f51bb51'},
#            {'id': '1Seazf707duYqPnjbKNArm4RAjLzcivsh',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '1423449a275a6c78815ac45f75a757452e2766'},
#            {'id': '1ShI2_dDad-EBLKyCbATBeelvnFOoErd7',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': 'b2765e64e733ea01ec6b4d7f6b02d760c2ea3f'},
#            {'id': '1SjnVwXG7pZfgu_fFPeBezvmphqfQ-q6S',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '488a00036b34ae7fe260253b62446ffe9436a9'},
#            {'id': '1SnwYRS8o386ZmgVJ3UJsB6c4dRELmLma',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '2f93d5f71406c24b2035039188485d06b37411'},
#            {'id': '1Sr5QetHj6PwWopMcM7bJmU5btXaBSKBN',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '26d801260e5e56a41f7afe9e7a0e9b8c20202d'},
#            {'id': '1Sswc2te2r-hqpWqsvommevnU3XzrFTpF',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '761c6c2d0a82ca11dfc67aaf3a6d207d1c92fa'},
#            {'id': '1SvMobA2yXnS4mYUGV9mA-9HynGM20rBY',
#             'kind': 'drive#file',
#             'mimeType': 'application/octet-stream',
#             'name': '695430031210cb26e16497f5390db90ed92299'}],
#  'incompleteSearch': False,
#  'kind': 'drive#fileList',
#  'nextPageToken': '~!!~AI9FV7SUl2nX8ULeQHNH6nGEo_s3Xxy3uuMRJ2JXwJ7n8V3363AnyE1ZoPeMMi96W1DPcJKp5rfperLp1tC17mzvEOXGHKA0ODIuOL2bd-zBSL5k-aPZN1jNL_HnBe-3yDbWKw6gkkfXPXonhIMBxFtvdaIkIIzCrfWzDcgsJOiPPOQOBuRFlhfy_r2zSvciLNmNkVmuGr5svjSFWHcQjLHRifoVd8PHgMe75aJWoKy6ZZUR3cCNUpV9rVQlNGEtJ59OdPqEWN42JD_io52nnT8YwqkRK91RHA=='}
